# %%
# print all the outputs in a cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("creditcard.csv")

# %%
features=['V1','V2','V3']

# %%
fig, ax = plt.subplots(1,3,figsize=(14,1))

plt.subplot(1, 4, 1)
sns.distplot(df.V1[df.Class==0])
sns.distplot(df.V1[df.Class==1])

plt.subplot(1, 4, 2)
sns.distplot(df.V2[df.Class==0])
sns.distplot(df.V2[df.Class==1])

plt.subplot(1, 4, 3)
sns.distplot(df.V3[df.Class==0])
sns.distplot(df.V3[df.Class==1])

plt.subplot(1, 4, 4)
sns.distplot(df.V4[df.Class==0])
sns.distplot(df.V4[df.Class==1])

# %%
for i in [1,5,9,13,17,21,25]:
    
    feature1 = 'V'+str(i)
    feature2 = 'V'+str(i+1)
    feature3 = 'V'+str(i+2)
    feature4 = 'V'+str(i+3)

    fig, ax = plt.subplots(1,4,figsize=(14,1));
    
    plt.subplot(1, 4, 1);
    sns.distplot(df[feature1][df.Class==0]);
    sns.distplot(df[feature1][df.Class==1]);

    plt.subplot(1, 4, 2);
    sns.distplot(df[feature2][df.Class==0]);
    sns.distplot(df[feature2][df.Class==1]);

    plt.subplot(1, 4, 3);
    sns.distplot(df[feature3][df.Class==0]);
    sns.distplot(df[feature3][df.Class==1]);

    plt.subplot(1, 4, 4);
    sns.distplot(df[feature4][df.Class==0]);
    sns.distplot(df[feature4][df.Class==1]);

# %%
sns.distplot(df['Amount'][df.Class==0])
sns.distplot(df['Amount'][df.Class==1])

# %%
fig, ax = plt.subplots(1,3,figsize=(14,1))

plt.subplot(1, 4, 1)
sns.distplot(df.V1[df.Class==0])
sns.distplot(df.V1[df.Class==1])

plt.subplot(1, 4, 2)
sns.distplot(df.V3[df.Class==0])
sns.distplot(df.V3[df.Class==1])

plt.subplot(1, 4, 3)
sns.distplot(df.V4[df.Class==0])
sns.distplot(df.V4[df.Class==1])

plt.subplot(1, 4, 4)
sns.distplot(df.V9[df.Class==0])
sns.distplot(df.V9[df.Class==1])

fig, ax = plt.subplots(1,3,figsize=(14,1))

plt.subplot(1, 4, 1)
sns.distplot(df.V10[df.Class==0])
sns.distplot(df.V10[df.Class==1])

plt.subplot(1, 4, 2)
sns.distplot(df.V11[df.Class==0])
sns.distplot(df.V11[df.Class==1])

plt.subplot(1, 4, 3)
sns.distplot(df.V12[df.Class==0])
sns.distplot(df.V12[df.Class==1])

plt.subplot(1, 4, 4)
sns.distplot(df.V14[df.Class==0])
sns.distplot(df.V14[df.Class==1])

fig, ax = plt.subplots(1,3,figsize=(14,1))

plt.subplot(1, 4, 1)
sns.distplot(df.V16[df.Class==0])
sns.distplot(df.V16[df.Class==1])

plt.subplot(1, 4, 2)
sns.distplot(df.V17[df.Class==0])
sns.distplot(df.V17[df.Class==1])

plt.subplot(1, 4, 3)
sns.distplot(df.V19[df.Class==0])
sns.distplot(df.V19[df.Class==1])

plt.subplot(1, 4, 4)
sns.distplot(df.Amount[df.Class==0])
sns.distplot(df.Amount[df.Class==1])

# %%
def draw_neural_net(ax, left, right, bottom, top, layer_sizes):
    '''
    Draw a neural network cartoon using matplotilb.
    
    :usage:
        >>> fig = plt.figure(figsize=(12, 12))
        >>> draw_neural_net(fig.gca(), .1, .9, .1, .9, [4, 7, 2])
    
    :parameters:
        - ax : matplotlib.axes.AxesSubplot
            The axes on which to plot the cartoon (get e.g. by plt.gca())
        - left : float
            The center of the leftmost node(s) will be placed here
        - right : float
            The center of the rightmost node(s) will be placed here
        - bottom : float
            The center of the bottommost node(s) will be placed here
        - top : float
            The center of the topmost node(s) will be placed here
        - layer_sizes : list of int
            List of layer sizes, including input and output dimensionality
    '''
    n_layers = len(layer_sizes)
    v_spacing = (top - bottom)/float(max(layer_sizes))
    h_spacing = (right - left)/float(len(layer_sizes) - 1)
    # Nodes
    for n, layer_size in enumerate(layer_sizes):
        layer_top = v_spacing*(layer_size - 1)/2. + (top + bottom)/2.
        for m in range(layer_size):
            circle = plt.Circle((n*h_spacing + left, layer_top - m*v_spacing), v_spacing/4.,
                                color='w', ec='k', zorder=4)
            ax.add_artist(circle)
    # Edges
    for n, (layer_size_a, layer_size_b) in enumerate(zip(layer_sizes[:-1], layer_sizes[1:])):
        layer_top_a = v_spacing*(layer_size_a - 1)/2. + (top + bottom)/2.
        layer_top_b = v_spacing*(layer_size_b - 1)/2. + (top + bottom)/2.
        for m in range(layer_size_a):
            for o in range(layer_size_b):
                line = plt.Line2D([n*h_spacing + left, (n + 1)*h_spacing + left],
                                  [layer_top_a - m*v_spacing, layer_top_b - o*v_spacing], c='b')
                ax.add_artist(line)

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.gca()
ax.axis('off')
draw_neural_net(ax, .1, .9, .1, .9, [30, 20, 10,5,10,20,30])
fig.savefig('nn.png')
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.gca()
ax.axis('off')
draw_neural_net(ax, .1, .9, .1, .9, [30, 20, 10,5,2])
fig.savefig('nn.png')
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
def draw_neural_net_colors(ax, left, right, bottom, top, layer_sizes):
    '''
    Draw a neural network cartoon using matplotilb.
    
    :usage:
        >>> fig = plt.figure(figsize=(12, 12))
        >>> draw_neural_net(fig.gca(), .1, .9, .1, .9, [4, 7, 2])
    
    :parameters:
        - ax : matplotlib.axes.AxesSubplot
            The axes on which to plot the cartoon (get e.g. by plt.gca())
        - left : float
            The center of the leftmost node(s) will be placed here
        - right : float
            The center of the rightmost node(s) will be placed here
        - bottom : float
            The center of the bottommost node(s) will be placed here
        - top : float
            The center of the topmost node(s) will be placed here
        - layer_sizes : list of int
            List of layer sizes, including input and output dimensionality
    '''
    n_layers = len(layer_sizes)
    v_spacing = (top - bottom)/float(max(layer_sizes))
    h_spacing = (right - left)/float(len(layer_sizes) - 1)
    # Nodes
    for n, layer_size in enumerate(layer_sizes):
        layer_top = v_spacing*(layer_size - 1)/2. + (top + bottom)/2.
        for m in range(layer_size):
            circle = plt.Circle((n*h_spacing + left, layer_top - m*v_spacing), v_spacing/4.,
                                color='w', ec='k', zorder=4)
            ax.add_artist(circle)
    # Edges
    for n, (layer_size_a, layer_size_b) in enumerate(zip(layer_sizes[:-1], layer_sizes[1:])):
        layer_top_a = v_spacing*(layer_size_a - 1)/2. + (top + bottom)/2.
        layer_top_b = v_spacing*(layer_size_b - 1)/2. + (top + bottom)/2.
        for m in range(layer_size_a):
            for o in range(layer_size_b):
                if n==0:
                    line = plt.Line2D([n*h_spacing + left, (n + 1)*h_spacing + left],
                                  [layer_top_a - m*v_spacing, layer_top_b - o*v_spacing], c='xkcd:bright green')
                    ax.add_artist(line)
                if n==1:
                    line = plt.Line2D([n*h_spacing + left, (n + 1)*h_spacing + left],
                                  [layer_top_a - m*v_spacing, layer_top_b - o*v_spacing], c='xkcd:blue violet')
                    ax.add_artist(line)
                if n==2:
                    line = plt.Line2D([n*h_spacing + left, (n + 1)*h_spacing + left],
                                  [layer_top_a - m*v_spacing, layer_top_b - o*v_spacing], c='r')
                    ax.add_artist(line)
                else:
                    line = plt.Line2D([n*h_spacing + left, (n + 1)*h_spacing + left],
                                  [layer_top_a - m*v_spacing, layer_top_b - o*v_spacing], c='k')
                    ax.add_artist(line)

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.gca()
ax.axis('off')
draw_neural_net_colors(ax, .1, .9, .1, .9, [30, 20, 10,5,10,20,30])
fig.savefig('nn.png')
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
layer_sizes=[30, 20, 10,5,10,20,30]
layer_sizes[:-1]
layer_sizes[1:]
list(zip(layer_sizes[:-1], layer_sizes[1:]))
# Out:
# [30, 20, 10, 5, 10, 20]
# [20, 10, 5, 10, 20, 30]
# [(30, 20), (20, 10), (10, 5), (5, 10), (10, 20), (20, 30)]

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.gca()
ax.axis('off')
draw_neural_net_colors(ax, .1, .9, .1, .9, [30, 20, 10,5,2])
fig.savefig('nn.png')
# Out:
# (0.0, 1.0, 0.0, 1.0)
